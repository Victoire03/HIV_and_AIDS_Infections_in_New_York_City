# %% [markdown]
# Dictionary for Clean Age and Gender

# %%
import pandas as pd

# %%
# Gender Dictionary: column names, data types and non-null count
df_Gender = pd.read_csv('df_Gender_cleaned.csv')
df_Gender

Gender_data_dict = pd.DataFrame({
    "Column Name": df_Gender.columns,
    "Data Type": df_Gender.dtypes.astype(str),
    "Non-Null Count": df_Gender.notnull().sum()
})

Gender_data_dict
# Out:
#                                                                                           Column Name  \
# YEAR                                                                                             YEAR
# GENDER BOROUGH                                                                         GENDER BOROUGH
# NEIGHBORHOOD                                                                             NEIGHBORHOOD
# SEX                                                                                               SEX
# RACE BY GENDER                                                                         RACE BY GENDER
# GENDER TOTAL NUMBER OF HIV DIAGNOSES                             GENDER TOTAL NUMBER OF HIV DIAGNOSES
# GENDER HIV DIAGNOSES PER 100,000 POPULATION               GENDER HIV DIAGNOSES PER 100,000 POPULATION
# GENDER TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAG...  GENDER TOTAL NUMBER OF CONCURRENT HIV/AIDS DIA...
# GENDER PROPORTION OF CONCURRENT HIV/AIDS DIAGNO...  GENDER PROPORTION OF CONCURRENT HIV/AIDS DIAGN...
# GENDER TOTAL NUMBER OF AIDS DIAGNOSES                           GENDER TOTAL NUMBER OF AIDS DIAGNOSES
# GENDER AIDS DIAGNOSES PER 100,000 POPULATION             GENDER AIDS DIAGNOSES PER 100,000 POPULATION
#
#                                                    Data Type  Non-Null Count
# YEAR                                                   int64            8976
# GENDER BOROUGH                                        object            6048
# NEIGHBORHOOD                                          object            8976
# SEX                                                   object            8976
# RACE BY GENDER                                        object            8976
# GENDER TOTAL NUMBER OF HIV DIAGNOSES                 float64            8960
# GENDER HIV DIAGNOSES PER 100,000 POPULATION          float64            8892
# GENDER TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAG...   float64            8972
# GENDER PROPORTION OF CONCURRENT HIV/AIDS DIAGNO...   float64            7081
# GENDER TOTAL NUMBER OF AIDS DIAGNOSES                float64            8963
# GENDER AIDS DIAGNOSES PER 100,000 POPULATION         float64            8895

# %%
# Age Dictionary: column names, data types and non-null count
df_Age = pd.read_csv('df_Age_cleaned.csv')
df_Age

Age_data_dict = pd.DataFrame({
    "Column Name": df_Age.columns,
    "Data Type": df_Age.dtypes.astype(str),
    "Non-Null Count": df_Age.notnull().sum()
})

Age_data_dict
# Out:
#                                                                                           Column Name  \
# YEAR                                                                                             YEAR
# NEIGHBORHOOD                                                                             NEIGHBORHOOD
# RACE BY AGE                                                                               RACE BY AGE
# AGE                                                                                               AGE
# AGE TOTAL NUMBER OF HIV DIAGNOSES                                   AGE TOTAL NUMBER OF HIV DIAGNOSES
# AGE HIV DIAGNOSES PER 100,000 POPULATION                     AGE HIV DIAGNOSES PER 100,000 POPULATION
# AGE TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES   AGE TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES
# AGE PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES...  AGE PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSE...
# AGE TOTAL NUMBER OF AIDS DIAGNOSES                                 AGE TOTAL NUMBER OF AIDS DIAGNOSES
# AGE AIDS DIAGNOSES PER 100,000 POPULATION                   AGE AIDS DIAGNOSES PER 100,000 POPULATION
# AGE BOROUGH                                                                               AGE BOROUGH
#
#                                                    Data Type  Non-Null Count
# YEAR                                                   int64            8976
# NEIGHBORHOOD                                          object            8976
# RACE BY AGE                                           object            8976
# AGE                                                   object            8976
# AGE TOTAL NUMBER OF HIV DIAGNOSES                    float64            8857
# AGE HIV DIAGNOSES PER 100,000 POPULATION             float64            7481
# AGE TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES    float64            8941
# AGE PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES...   float64            7435
# AGE TOTAL NUMBER OF AIDS DIAGNOSES                   float64            8896
# AGE AIDS DIAGNOSES PER 100,000 POPULATION            float64            7520
# AGE BOROUGH                                           object             372
